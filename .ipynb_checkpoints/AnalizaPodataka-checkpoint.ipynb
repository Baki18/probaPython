# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("bank-additional.csv", delimiter=';')

# %%
data.shape
# Out:
# (4119, 21)

# %%
data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...       2.0    999       0.0  nonexistent
# 1  telephone   may         fri  ...       4.0    999       0.0  nonexistent
# 2  telephone   jun         wed  ...       1.0    999       0.0  nonexistent
# 3  telephone   jun         fri  ...       3.0    999       0.0  nonexistent
# 4   cellular   nov         mon  ...       1.0    999       0.0  nonexistent
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4116 non-null   float64
#  11  campaign        4114 non-null   float64
#  12  pdays           4119 non-null   int64
#  13  previous        4117 non-null   float64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4116 non-null   float64
#  16  cons.price.idx  4117 non-null   float64
# ...

# %%
data.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays               int64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed        object
# y                  object
# dtype: object

# %%
data.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          3
# campaign          5
# pdays             0
# previous          2
# poutcome          0
# emp.var.rate      3
# cons.price.idx    2
# cons.conf.idx     2
# euribor3m         2
# nr.employed       1
# y                 1
# dtype: int64

# %%
data.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.041518 -0.014027 -0.043425  0.050709
# duration        0.041518  1.000000 -0.084864 -0.046941  0.025650
# campaign       -0.014027 -0.084864  1.000000  0.058578 -0.091208
# pdays          -0.043425 -0.046941  0.058578  1.000000 -0.587930
# previous        0.050709  0.025650 -0.091208 -0.587930  1.000000
# emp.var.rate   -0.018516 -0.028231  0.175731  0.270708 -0.415220
# cons.price.idx -0.000245  0.016422  0.144740  0.058420 -0.164824
# cons.conf.idx   0.095475 -0.035909  0.008025 -0.090662 -0.051946
# euribor3m      -0.012596 -0.011527  0.012374  0.009715 -0.015494
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# age                -0.018516       -0.000245       0.095475  -0.012596
# duration           -0.028231        0.016422      -0.035909  -0.011527
# campaign            0.175731        0.144740       0.008025   0.012374
# ...

# %%
data.replace(to_replace="unknown", value=None, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4080 non-null   object
#  2   marital         4108 non-null   object
#  3   education       3952 non-null   object
#  4   default         3316 non-null   object
#  5   housing         4014 non-null   object
#  6   loan            4014 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4116 non-null   float64
#  11  campaign        4114 non-null   float64
#  12  pdays           4119 non-null   int64
#  13  previous        4117 non-null   float64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4116 non-null   float64
#  16  cons.price.idx  4117 non-null   float64
# ...

# %%
data.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4116.000000  4114.000000  4119.000000  4117.000000
# mean     40.113620   256.869048     2.534273   960.422190     0.190430
# std      10.313362   254.763913     2.566673   191.922786     0.541904
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.250000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m
# count   4116.000000     4117.000000    4117.000000  4117.000000
# mean       0.084694       93.579540     -40.486358     4.858993
# std        1.563361        0.579442       4.639840    79.432456
# min       -3.400000       92.201000     -50.800000     0.635000
# ...

# %%
numVar = ['age', 'duration', 'campaign', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m']
katVar = [el for el in data.columns.to_list() if el not in numVar]

# %%
for var in numVar:
    plt.title(var)
    plt.hist(data[var])
    plt.show()

# %%
data.isnull().sum()
# Out:
# age                 0
# job                39
# marital            11
# education         167
# default           803
# housing           105
# loan              105
# contact             0
# month               0
# day_of_week         0
# duration            3
# campaign            5
# pdays               0
# previous            2
# poutcome            0
# emp.var.rate        3
# cons.price.idx      2
# cons.conf.idx       2
# euribor3m           2
# nr.employed         1
# y                   1
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 1251

# %%
data.isnull().sum().sum()
# Out:
# 1251

# %%
data['y'].replace({'yes':1, 'no':0}, inplace=True)
# Out:
#       age          job  marital          education default housing  loan  \
# 0      30  blue-collar  married           basic.9y      no     yes    no
# 1      39     services   single        high.school      no      no    no
# 2      25     services  married        high.school      no     yes    no
# 3      38     services  married           basic.9y      no    None  None
# 4      47       admin.  married  university.degree      no     yes    no
# ...   ...          ...      ...                ...     ...     ...   ...
# 4114   30       admin.  married           basic.6y      no     yes   yes
# 4115   39       admin.  married        high.school      no     yes    no
# 4116   27      student   single        high.school      no      no    no
# 4117   58       admin.  married        high.school      no      no    no
# 4118   34   management   single        high.school      no     yes    no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
data.loc[data['y']==0,:]
# Out:
#       age          job  marital          education default housing  loan  \
# 0      30  blue-collar  married           basic.9y      no     yes    no
# 1      39     services   single        high.school      no      no    no
# 2      25     services  married        high.school      no     yes    no
# 3      38     services  married           basic.9y      no    None  None
# 4      47       admin.  married  university.degree      no     yes    no
# ...   ...          ...      ...                ...     ...     ...   ...
# 4114   30       admin.  married           basic.6y      no     yes   yes
# 4115   39       admin.  married        high.school      no     yes    no
# 4116   27      student   single        high.school      no      no    no
# 4117   58       admin.  married        high.school      no      no    no
# 4118   34   management   single        high.school      no     yes    no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
import pandas as pd

# create a sample DataFrame
df = pd.DataFrame({'category': ['A', 'B', 'C', 'A', 'C', 'B']})

# apply one-hot encoding to the 'category' column and append the resulting columns to the original DataFrame
encoded_df = pd.get_dummies(df['category'], prefix='category')
df = pd.concat([df, encoded_df], axis=1)

# output the resulting DataFrame
print(df)
# Out:
#   category  category_A  category_B  category_C
# 0        A           1           0           0
# 1        B           0           1           0
# 2        C           0           0           1
# 3        A           1           0           0
# 4        C           0           0           1
# 5        B           0           1           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4080 non-null   object
#  2   marital         4108 non-null   object
#  3   education       3952 non-null   object
#  4   default         3316 non-null   object
#  5   housing         4014 non-null   object
#  6   loan            4014 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4116 non-null   float64
#  11  campaign        4114 non-null   float64
#  12  pdays           4119 non-null   int64
#  13  previous        4117 non-null   float64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4116 non-null   float64
#  16  cons.price.idx  4117 non-null   float64
# ...

# %%
data['nr.employed'].value_counts().sum()
# Out:
# 4118
