# %%
import pandas as pd
from fontTools.ttLib.tables.asciiTable import asciiTable
from jupyterthemes.jtplot import figsize
from numpy import invert
from wordcloud.wordcloud import colormap_color_func

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %% [markdown]
# Ucitavanje skupa podataka i analiza skupa podataka

# %% [markdown]
# Ucitavanje skupa podataka, storujemo u df

# %%
df = pd.read_csv('bank-additional.csv', delimiter=';')
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...       2.0    999       0.0  nonexistent
# 1  telephone   may         fri  ...       4.0    999       0.0  nonexistent
# 2  telephone   jun         wed  ...       1.0    999       0.0  nonexistent
# 3  telephone   jun         fri  ...       3.0    999       0.0  nonexistent
# 4   cellular   nov         mon  ...       1.0    999       0.0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         -1.8          92.893          -46.2      1.313       5099.1  no
# 1          1.1          93.994          -36.4      4.855         5191  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3          1.4          94.465          -41.8      4.959       5228.1  no
# 4         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %% [markdown]
# Osnovno o skupu podataka:

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays               int64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed        object
# y                  object
# dtype: object

# %%
df.shape
# Out:
# (4119, 21)

# %%
print(df.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4116 non-null   float64
#  11  campaign        4114 non-null   float64
#  12  pdays           4119 non-null   int64
#  13  previous        4117 non-null   float64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4116 non-null   float64
#  16  cons.price.idx  4117 non-null   float64
#  17  cons.conf.idx   4117 non-null   float64
#  18  euribor3m       4117 non-null   float64
#  19  nr.employed     4118 non-null   object
#  20  y               4118 non-null   object
# dtypes: float64(7), int64(2), object(12)
# memory usage: 675.9+ KB

# %% [markdown]
# Deskriptivna statistika

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4116.000000  4114.000000  4119.000000  4117.000000
# mean     40.113620   256.869048     2.534273   960.422190     0.190430
# std      10.313362   254.763913     2.566673   191.922786     0.541904
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.250000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m
# count   4116.000000     4117.000000    4117.000000  4117.000000
# mean       0.084694       93.579540     -40.486358     4.858993
# std        1.563361        0.579442       4.639840    79.432456
# min       -3.400000       92.201000     -50.800000     0.635000
# 25%       -1.800000       93.075000     -42.700000     1.334000
# 50%        1.100000       93.749000     -41.800000     4.857000
# 75%        1.400000       93.994000     -36.400000     4.961000
# max        1.400000       94.767000       1.266000  5099.100000

# %%
df.sample(5)
# Out:
#       age          job  marital          education default  housing     loan  \
# 1831   61      unknown   single           basic.4y      no      yes      yes
# 3839   38       admin.  married        high.school      no  unknown  unknown
# 527    41  blue-collar  married           basic.9y      no       no       no
# 3422   30     services   single        high.school      no      yes       no
# 1810   38       admin.  married  university.degree      no      yes      yes
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 1831   cellular   may         tue  ...       3.0    999       0.0
# 3839   cellular   nov         thu  ...       1.0    999       0.0
# 527   telephone   may         tue  ...       1.0    999       0.0
# 3422   cellular   aug         thu  ...       2.0    999       0.0
# 1810   cellular   aug         fri  ...       1.0    999       0.0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 1831  nonexistent         -1.8          92.893          -46.2      1.266
# 3839  nonexistent         -0.1          93.200          -42.0      4.076
# 527   nonexistent          1.1          93.994          -36.4      4.856
# 3422  nonexistent         -2.9          92.201          -31.4      0.873
# 1810  nonexistent          1.4          93.444          -36.1      4.963
#
#       nr.employed    y
# 1831       5099.1   no
# 3839       5195.8   no
# 527          5191   no
# 3422       5076.2  yes
# 1810       5228.1   no
#
# [5 rows x 21 columns]

# %% [markdown]
# Mozemo da uocimo razlicite vrste poslova iz naseg skupa podataka

# %%
df['job'].value_counts()
# Out:
# admin.           1012
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# Name: job, dtype: int64

# %%
df['education'].value_counts()
# Out:
# university.degree      1264
# high.school             921
# basic.9y                574
# professional.course     535
# basic.4y                429
# basic.6y                228
# unknown                 167
# illiterate                1
# Name: education, dtype: int64

# %% [markdown]
# Kada hocemo da pokazemo broj pojavljivanja za vise kolona:

# %%
pd.crosstab(df['job'], df['education'])
# Out:
# education      basic.4y  basic.6y  basic.9y  high.school  illiterate  \
# job
# admin.                8        20        44          311           0
# blue-collar         222       152       324           89           0
# entrepreneur         18         5        23           17           0
# housemaid            52         9         5           11           0
# management           13         8        20           41           0
# retired              59         6        11           24           1
# self-employed        11         2        28           15           0
# services             16        12        56          254           0
# student               2         0         5           35           0
# technician            7        10        34           95           0
# unemployed           13         3        18           23           0
# unknown               8         1         6            6           0
#
# education      professional.course  university.degree  unknown
# job
# admin.                          38                567       24
# blue-collar                     49                  6       42
# entrepreneur                    14                 64        7
# housemaid                        8                 22        3
# management                       7                220       15
# retired                         28                 32        5
# self-employed                   12                 87        4
# services                        25                 18       12
# student                          8                 12       20
# technician                     330                196       19
# unemployed                      14                 37        3
# unknown                          2                  3       13

# %%
pd.crosstab(df['job'], df['education'], normalize=True)
# Out:
# education      basic.4y  basic.6y  basic.9y  high.school  illiterate  \
# job
# admin.         0.001942  0.004856  0.010682     0.075504    0.000000
# blue-collar    0.053897  0.036902  0.078660     0.021607    0.000000
# entrepreneur   0.004370  0.001214  0.005584     0.004127    0.000000
# housemaid      0.012624  0.002185  0.001214     0.002671    0.000000
# management     0.003156  0.001942  0.004856     0.009954    0.000000
# retired        0.014324  0.001457  0.002671     0.005827    0.000243
# self-employed  0.002671  0.000486  0.006798     0.003642    0.000000
# services       0.003884  0.002913  0.013596     0.061665    0.000000
# student        0.000486  0.000000  0.001214     0.008497    0.000000
# technician     0.001699  0.002428  0.008254     0.023064    0.000000
# unemployed     0.003156  0.000728  0.004370     0.005584    0.000000
# unknown        0.001942  0.000243  0.001457     0.001457    0.000000
#
# education      professional.course  university.degree   unknown
# job
# admin.                    0.009226           0.137655  0.005827
# blue-collar               0.011896           0.001457  0.010197
# entrepreneur              0.003399           0.015538  0.001699
# housemaid                 0.001942           0.005341  0.000728
# management                0.001699           0.053411  0.003642
# retired                   0.006798           0.007769  0.001214
# self-employed             0.002913           0.021122  0.000971
# services                  0.006069           0.004370  0.002913
# student                   0.001942           0.002913  0.004856
# technician                0.080117           0.047584  0.004613
# unemployed                0.003399           0.008983  0.000728
# unknown                   0.000486           0.000728  0.003156

# %% [markdown]
# Na primer da vidimo broj menadzera koji imaju ispod 30 godina

# %%
df[(df['job'].str.contains('management')) & (df['age']<30)].sort_values(by=['age'])
# Out:
#       age         job  marital          education  default housing loan  \
# 368    23  management   single  university.degree       no     yes   no
# 1131   26  management   single  university.degree       no     yes   no
# 3165   26  management   single  university.degree       no      no   no
# 3161   26  management   single  university.degree       no      no   no
# 2470   26  management   single  university.degree  unknown     yes   no
# 419    27  management   single  university.degree       no     yes   no
# 1294   27  management  married  university.degree       no      no   no
# 701    28  management   single           basic.9y       no     yes   no
# 1241   28  management   single  university.degree       no      no   no
# 1852   28  management   single  university.degree       no     yes   no
# 2773   28  management   single  university.degree       no      no   no
# 2277   28  management  married  university.degree       no      no   no
# 130    29  management  married  university.degree       no      no  yes
# 3748   29  management   single  university.degree       no      no   no
# 2833   29  management   single  university.degree       no      no  yes
# 2085   29  management   single  university.degree       no      no   no
# 2091   29  management  married  university.degree       no     yes   no
# 3848   29  management  married  university.degree       no      no   no
# 1342   29  management   single  university.degree       no     yes  yes
# 1299   29  management   single  university.degree       no     yes   no
# 255    29  management  married  university.degree       no     yes  yes
# 2590   29  management   single  university.degree       no     yes   no
# 3972   29  management   single  university.degree       no      no  yes
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 368    cellular   jul         tue  ...       2.0    999       0.0
# 1131   cellular   nov         mon  ...       5.0    999       0.0
# 3165   cellular   mar         thu  ...       1.0    999       0.0
# 3161   cellular   sep         fri  ...       2.0    999       0.0
# 2470   cellular   jul         wed  ...       1.0    999       0.0
# 419   telephone   may         tue  ...       2.0    999       0.0
# 1294   cellular   apr         mon  ...       1.0    999       0.0
# 701   telephone   may         thu  ...       1.0    999       0.0
# 1241  telephone   jun         thu  ...       5.0    999       0.0
# 1852   cellular   sep         tue  ...       1.0    999       0.0
# 2773   cellular   jul         fri  ...       3.0    999       0.0
# 2277  telephone   jun         wed  ...       2.0    999       0.0
# 130    cellular   aug         wed  ...       2.0    999       0.0
# 3748  telephone   may         fri  ...       1.0    999       0.0
# 2833   cellular   nov         tue  ...       1.0    999       0.0
# 2085  telephone   may         wed  ...       2.0    999       0.0
# 2091   cellular   aug         thu  ...       1.0      4       2.0
# 3848   cellular   nov         fri  ...       4.0    999       0.0
# 1342  telephone   may         mon  ...       3.0    999       0.0
# 1299   cellular   aug         tue  ...       2.0    999       0.0
# 255    cellular   aug         tue  ...       2.0    999       0.0
# 2590   cellular   may         fri  ...       2.0    999       1.0
# 3972   cellular   aug         tue  ...       1.0    999       0.0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 368   nonexistent          1.4          93.918          -42.7      4.961
# 1131  nonexistent         -1.1          94.767          -50.8      1.039
# 3165  nonexistent         -1.8          92.843          -50.0      1.650
# 3161  nonexistent         -3.4          92.379          -29.8      0.803
# 2470  nonexistent          1.4          93.918          -42.7      4.962
# 419   nonexistent          1.1          93.994          -36.4      4.856
# 1294  nonexistent         -1.8          93.075          -47.1      1.392
# 701   nonexistent         -1.8          92.893          -46.2      1.266
# 1241  nonexistent          1.4          94.465          -41.8      4.958
# 1852  nonexistent         -3.4          92.379          -29.8      0.819
# 2773  nonexistent          1.4          93.918          -42.7      4.957
# 2277  nonexistent          1.4          94.465          -41.8      4.962
# 130   nonexistent          1.4          93.444          -36.1      4.967
# 3748  nonexistent          1.1          93.994          -36.4      4.855
# 2833  nonexistent         -0.1          93.200          -42.0      4.153
# 2085  nonexistent          1.1          93.994          -36.4      4.857
# 2091      success         -2.9          92.201          -31.4      0.873
# 3848  nonexistent         -0.1          93.200          -42.0      4.021
# 1342  nonexistent          1.1          93.994          -36.4      4.857
# 1299  nonexistent          1.4          93.444          -36.1      4.963
# 255   nonexistent          1.4          93.444          -36.1      4.966
# 2590      failure         -1.8          92.893          -46.2      1.313
# 3972  nonexistent          1.4          93.444          -36.1      4.963
#
#       nr.employed    y
# 368        5228.1   no
# 1131       4963.6   no
# 3165       5099.1  yes
# 3161       5017.5   no
# 2470       5228.1   no
# 419          5191   no
# 1294       5099.1   no
# 701        5099.1   no
# 1241       5228.1  yes
# 1852       5017.5   no
# 2773       5228.1   no
# 2277       5228.1  yes
# 130        5228.1   no
# 3748         5191   no
# 2833       5195.8   no
# 2085         5191   no
# 2091       5076.2   no
# 3848       5195.8   no
# 1342         5191   no
# 1299       5228.1   no
# 255        5228.1   no
# 2590       5099.1   no
# 3972       5228.1   no
#
# [23 rows x 21 columns]

# %% [markdown]
# Koliko ima razlicitih kategorija za atribut 'marital'

# %%
np.unique(df['marital'])
# Out:
# array(['divorced', 'married', 'single', 'unknown'], dtype=object)

# %%
np.unique(df['job'])
# Out:
# array(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'], dtype=object)

# %%
np.unique(df['contact'])
# Out:
# array(['cellular', 'telephone'], dtype=object)

# %% [markdown]
# Korelacije izmedju atributa:

# %%
print("Correlation Matrix")
df.corr()
# Out:
# Correlation Matrix
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.041518 -0.014027 -0.043425  0.050709
# duration        0.041518  1.000000 -0.084864 -0.046941  0.025650
# campaign       -0.014027 -0.084864  1.000000  0.058578 -0.091208
# pdays          -0.043425 -0.046941  0.058578  1.000000 -0.587930
# previous        0.050709  0.025650 -0.091208 -0.587930  1.000000
# emp.var.rate   -0.018516 -0.028231  0.175731  0.270708 -0.415220
# cons.price.idx -0.000245  0.016422  0.144740  0.058420 -0.164824
# cons.conf.idx   0.095475 -0.035909  0.008025 -0.090662 -0.051946
# euribor3m      -0.012596 -0.011527  0.012374  0.009715 -0.015494
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# age                -0.018516       -0.000245       0.095475  -0.012596
# duration           -0.028231        0.016422      -0.035909  -0.011527
# campaign            0.175731        0.144740       0.008025   0.012374
# pdays               0.270708        0.058420      -0.090662   0.009715
# previous           -0.415220       -0.164824      -0.051946  -0.015494
# emp.var.rate        1.000000        0.755721       0.189664   0.002375
# cons.price.idx      0.755721        1.000000       0.042221  -0.004134
# cons.conf.idx       0.189664        0.042221       1.000000   0.146225
# euribor3m           0.002375       -0.004134       0.146225   1.000000

# %%
df['age'].corr(df['duration'])
# Out:
# 0.04151813249745746

# %%
c = df.corr().abs()
c = c[c!=1.000]
s = c.unstack().drop_duplicates()
so = s.sort_values(kind="quicksort", ascending=False)
so
#so.__len__()
# Out:
# emp.var.rate    cons.price.idx    0.755721
# pdays           previous          0.587930
# previous        emp.var.rate      0.415220
# pdays           emp.var.rate      0.270708
# emp.var.rate    cons.conf.idx     0.189664
# campaign        emp.var.rate      0.175731
# previous        cons.price.idx    0.164824
# cons.conf.idx   euribor3m         0.146225
# campaign        cons.price.idx    0.144740
# age             cons.conf.idx     0.095475
# campaign        previous          0.091208
# pdays           cons.conf.idx     0.090662
# duration        campaign          0.084864
# campaign        pdays             0.058578
# pdays           cons.price.idx    0.058420
# previous        cons.conf.idx     0.051946
# age             previous          0.050709
# duration        pdays             0.046941
# age             pdays             0.043425
# cons.price.idx  cons.conf.idx     0.042221
# age             duration          0.041518
# duration        cons.conf.idx     0.035909
#                 emp.var.rate      0.028231
#                 previous          0.025650
# age             emp.var.rate      0.018516
# duration        cons.price.idx    0.016422
# previous        euribor3m         0.015494
# age             campaign          0.014027
#                 euribor3m         0.012596
# campaign        euribor3m         0.012374
# duration        euribor3m         0.011527
# pdays           euribor3m         0.009715
# campaign        cons.conf.idx     0.008025
# cons.price.idx  euribor3m         0.004134
# emp.var.rate    euribor3m         0.002375
# age             cons.price.idx    0.000245
#                 age                    NaN
# dtype: float64

# %%
dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr >= .1) | (dfCorr <= -.1)) & (dfCorr !=1.000)]
plt.figure(figsize=(40,20))
sn.heatmap(filteredDf, annot=True, cmap="Reds")
sn.set(font_scale=7)
plt.show()

# %%
df.sample(30)
# Out:
#       age          job   marital            education  default  housing  \
# 3436   53  blue-collar    single             basic.9y       no  unknown
# 2665   46   technician  divorced  professional.course       no      yes
# 3135   45       admin.   married    university.degree       no       no
# 1572   35       admin.   married          high.school  unknown       no
# 813    42       admin.   married    university.degree       no      yes
# 1019   67      retired   married              unknown       no       no
# 3932   44   technician  divorced  professional.course       no      yes
# 3842   33   technician   married  professional.course       no       no
# 929    41  blue-collar   married             basic.9y  unknown       no
# 4046   35       admin.   married    university.degree       no      yes
# 4042   40  blue-collar    single             basic.9y       no  unknown
# 3660   34       admin.  divorced    university.degree       no      yes
# 1652   44     services  divorced          high.school       no      yes
# 3088   45       admin.  divorced    university.degree       no      yes
# 3834   34       admin.   married    university.degree       no       no
# 1693   29       admin.   married          high.school       no      yes
# 444    49       admin.   married          high.school       no       no
# 3050   42       admin.   married    university.degree       no       no
# 1306   34   technician   married  professional.course       no  unknown
# 954    24       admin.    single          high.school       no      yes
# 3600   46   technician  divorced    university.degree       no       no
# 1131   26   management    single    university.degree       no      yes
# 2008   37     services  divorced             basic.9y       no      yes
# 3415   55   management   married    university.degree       no       no
# 3300   51    housemaid   married             basic.4y  unknown       no
# 4024   31     services   married             basic.9y       no      yes
# 487    24  blue-collar    single             basic.9y       no      yes
# 936    64      unknown   married              unknown       no      yes
# 960    46  blue-collar    single             basic.9y  unknown      yes
# 1962   39   technician   married  professional.course  unknown      yes
#
#          loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 3436  unknown   cellular   mar         thu  ...       1.0      9       2.0
# 2665       no   cellular   jul         tue  ...       5.0    999       0.0
# 3135       no  telephone   may         fri  ...       2.0    999       0.0
# 1572       no   cellular   may         fri  ...       1.0    999       0.0
# 813        no   cellular   may         mon  ...       5.0    999       0.0
# 1019       no   cellular   oct         thu  ...       2.0    999       0.0
# 3932       no   cellular   jul         tue  ...       2.0    999       0.0
# 3842       no   cellular   jun         tue  ...       2.0    999       0.0
# 929        no  telephone   jun         thu  ...       2.0    999       0.0
# 4046       no   cellular   oct         thu  ...       1.0    999       1.0
# 4042  unknown   cellular   nov         wed  ...       4.0    999       0.0
# 3660       no   cellular   may         tue  ...       4.0    999       0.0
# 1652       no   cellular   may         thu  ...       1.0    999       0.0
# 3088       no   cellular   aug         mon  ...       5.0    999       0.0
# 3834       no   cellular   jul         tue  ...       2.0    999       0.0
# 1693      yes   cellular   aug         mon  ...       3.0    999       0.0
# 444        no   cellular   aug         fri  ...       1.0    999       0.0
# 3050       no   cellular   nov         mon  ...       2.0    999       0.0
# 1306  unknown   cellular   may         thu  ...       3.0    999       0.0
# 954       yes   cellular   mar         wed  ...       1.0    999       0.0
# 3600       no  telephone   jun         fri  ...       3.0    999       0.0
# 1131       no   cellular   nov         mon  ...       5.0    999       0.0
# 2008       no   cellular   jul         wed  ...       1.0    999       0.0
# 3415       no   cellular   aug         thu  ...       5.0    999       0.0
# 3300       no   cellular   aug         fri  ...       1.0    999       0.0
# 4024       no  telephone   jun         mon  ...       1.0    999       0.0
# 487        no   cellular   jul         fri  ...       2.0    999       0.0
# 936        no  telephone   aug         fri  ...       4.0    999       0.0
# 960        no   cellular   jul         thu  ...       1.0    999       0.0
# 1962       no   cellular   aug         wed  ...       2.0    999       0.0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 3436      success         -1.8          93.369          -34.8      0.643
# 2665  nonexistent          1.4          93.918          -42.7      4.961
# 3135  nonexistent          1.1          93.994          -36.4      4.857
# 1572  nonexistent         -1.8          92.893          -46.2      1.250
# 813   nonexistent         -1.8          92.893          -46.2      1.354
# 1019  nonexistent         -3.4          92.431          -26.9      0.722
# 3932  nonexistent          1.4          93.918          -42.7      4.961
# 3842  nonexistent         -2.9          92.963          -40.8      1.262
# 929   nonexistent          1.4          94.465          -41.8      4.866
# 4046      failure         -3.4          92.431          -26.9      0.740
# 4042  nonexistent         -0.1          93.200          -42.0      4.120
# 3660  nonexistent         -1.8          92.893          -46.2      1.291
# 1652  nonexistent         -1.8          92.893          -46.2      1.266
# 3088  nonexistent          1.4          93.444          -36.1      4.965
# 3834  nonexistent          1.4          93.918          -42.7      4.962
# 1693  nonexistent          1.4          93.444          -36.1      4.963
# 444   nonexistent          1.4          93.444          -36.1      4.966
# 3050  nonexistent         -0.1          93.200          -42.0      4.191
# 1306  nonexistent         -1.8          92.893          -46.2      1.327
# 954   nonexistent         -1.8          92.843          -50.0      1.602
# 3600  nonexistent          1.4          94.465          -41.8      4.967
# 1131  nonexistent         -1.1          94.767          -50.8      1.039
# 2008  nonexistent          1.4          93.918          -42.7      4.957
# 3415  nonexistent          1.4          93.444          -36.1      4.963
# 3300  nonexistent          1.4          93.444          -36.1      4.966
# 4024  nonexistent         -2.9          92.963          -40.8      1.266
# 487   nonexistent          1.4          93.918          -42.7      4.963
# 936   nonexistent         -1.7          94.027          -38.3      0.905
# 960   nonexistent          1.4          93.918          -42.7      4.963
# 1962  nonexistent          1.4          93.444          -36.1      4.964
#
#       nr.employed    y
# 3436       5008.7  yes
# 2665       5228.1   no
# 3135         5191   no
# 1572       5099.1  yes
# 813        5099.1   no
# 1019       5017.5   no
# 3932       5228.1   no
# 3842       5076.2   no
# 929        5228.1   no
# 4046       5017.5   no
# 4042       5195.8   no
# 3660       5099.1   no
# 1652       5099.1  yes
# 3088       5228.1   no
# 3834       5228.1   no
# 1693       5228.1   no
# 444        5228.1   no
# 3050       5195.8   no
# 1306       5099.1   no
# 954        5099.1  yes
# 3600       5228.1   no
# 1131       4963.6   no
# 2008       5228.1   no
# 3415       5228.1   no
# 3300       5228.1   no
# 4024       5076.2   no
# 487        5228.1   no
# 936        4991.6  yes
# 960        5228.1   no
# 1962       5228.1   no
#
# [30 rows x 21 columns]

# %% [markdown]
# Vidimo da ima vrednosti markiranih kao 'unkown'

# %%
df.replace("unknown", np.NaN, inplace=True)

# %% [markdown]
# Menjamo vrednosti za Nan vrednosti, kako bi mogli da koristimo fukciju isna()

# %%
df.isna().sum()
# Out:
# age                 0
# job                39
# marital            11
# education         167
# default           803
# housing           105
# loan              105
# contact             0
# month               0
# day_of_week         0
# duration            3
# campaign            5
# pdays               0
# previous            2
# poutcome            0
# emp.var.rate        3
# cons.price.idx      2
# cons.conf.idx       2
# euribor3m           2
# nr.employed         1
# y                   1
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 1251

# %%
kat = df.select_dtypes(include=['object'])
vred = df.select_dtypes(include=['int64','float64'])
vred
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0      30     487.0       2.0    999       0.0          -1.8          92.893
# 1      39     346.0       4.0    999       0.0           1.1          93.994
# 2      25     227.0       1.0    999       0.0           1.4          94.465
# 3      38      17.0       3.0    999       0.0           1.4          94.465
# 4      47      58.0       1.0    999       0.0          -0.1          93.200
# ...   ...       ...       ...    ...       ...           ...             ...
# 4114   30      53.0       1.0    999       0.0           1.4          93.918
# 4115   39     219.0       1.0    999       0.0           1.4          93.918
# 4116   27      64.0       2.0    999       1.0          -1.8          92.893
# 4117   58     528.0       1.0    999       0.0           1.4          93.444
# 4118   34     175.0       1.0    999       0.0          -0.1          93.200
#
#       cons.conf.idx  euribor3m
# 0             -46.2      1.313
# 1             -36.4      4.855
# 2             -41.8      4.962
# 3             -41.8      4.959
# 4             -42.0      4.191
# ...             ...        ...
# 4114          -42.7      4.958
# 4115          -42.7      4.959
# 4116          -46.2      1.354
# 4117          -36.1      4.966
# 4118          -42.0      4.120
#
# [4119 rows x 9 columns]

# %% [markdown]
# Raspodele date preko histograma:

# %%
for column in df.columns:
    plt.figure(figsize=(5,3))
    plt.xticks(size=11, rotation='vertical')
    plt.yticks(size=11)
    plt.locator_params(axis='y', nbins=5)
    plt.title(column, size=12)
    df[column].hist()
    plt.show()

# %%
plt.figure(figsize=(5,4))
plt.xticks(size=13)
plt.yticks(size=13)
plt.ylabel('density',fontdict={'fontsize':12})
plt.locator_params(axis='x', nbins=10)
df['duration'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['duration'].plot.kde(bw_method=0.05);

# %%
plt.figure(figsize=(5,4))
sn.distplot(df['age'])
sn.set(font_scale=7)
plt.show()
# Out:
# C:\Users\Korisnik\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(5,4))
sn.boxplot(data = df['cons.price.idx'])
sn.set(font_scale=0.2)
plt.show()

# %%
df['cons.price.idx'].plot(kind='box')
sn.set(font_scale=2)
plt.show()

# %%
sn.violinplot(data = df['cons.price.idx'])
sn.set(font_scale=0.5)
plt.show()

# %%
sn.countplot(x='age', data=df)
sn.set(font_scale=2)
plt.show()
#ne znam kako da promenim veolicinu za x ticks kod seaborn-a

# %%
sn.countplot(x='marital', data=df)
sn.set(font_scale=0.5)
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 8))
fig.suptitle('Vertikalni pod-plotovi')

sn.countplot(x='age', data=df, ax=axes[0])
sn.countplot(x='job', data=df, ax=axes[1])
# Out:
# <AxesSubplot:xlabel='job', ylabel='count'>

# %%
plt.scatter(df['cons.price.idx'], df['emp.var.rate'])
plt.xlabel('cons')
plt.ylabel('emp')
# Out:
# Text(0, 0.5, 'emp')

# %%
sn.pairplot(df.iloc[:, 3:6])
#ovo opet vidi sta se desava
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1096\1739768478.py in <module>
# ----> 1 sn.pairplot(df.iloc[:, 3:6])
#       2 #ovo opet vidi sta se desava
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
#    2098                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1231
#    1232         if not x_vars:
# -> 1233             raise ValueError("No variables found for grid columns.")
#    1234         if not y_vars:
#    1235             raise ValueError("No variables found for grid rows.")
#
# ValueError: No variables found for grid columns.

# %%
sn.jointplot(x='', y='Eve Calls', data=df)
